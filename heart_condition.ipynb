# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import csv
import pandas as pd
# %pylab inline --no-import-all
from scipy import stats
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
clev = pd.read_csv('cleveland_heart.csv')
swi = pd.read_csv('switzerland_heart.csv')
hun = pd.read_csv('hungarian_heart.csv')
lb= pd.read_csv('long_beach.csv')

# %%
clev.head(10)
# Out:
#    age  sex  chest_pain  resting_blod_pressuremm_hg  cholesterol_mg/dl  \
# 0   63    1           1                         145                233
# 1   67    1           4                         160                286
# 2   67    1           4                         120                229
# 3   37    1           3                         130                250
# 4   41    0           2                         130                204
# 5   56    1           2                         120                236
# 6   62    0           4                         140                268
# 7   57    0           4                         120                354
# 8   63    1           4                         130                254
# 9   53    1           4                         140                203
#
#    fasting_blood_sugar  resting_ekg  max_heart_rate  excersice_induced_angina  \
# 0                    1            2             150                         0
# ...

# %%
swi.head()
# Out:
#    age  sex  chest_pain resting_blod_pressuremm_hg  cholesterol_mg/dl  \
# 0   32    1           1                         95                  0
# 1   34    1           4                        115                  0
# 2   35    1           4                          ?                  0
# 3   36    1           4                        110                  0
# 4   38    0           4                        105                  0
#
#   fasting_blood_sugar resting_ekg max_heart_rate excersice_induced_angina  \
# 0                   ?           0            127                        0
# 1                   ?           ?            154                        0
# 2                   ?           0            130                        1
# 3                   ?           0            125                        1
# 4                   ?           0            166                        0
#
#   ST_depression_induced_by_exercise_relative_to_rest slope  \
# ...

# %%
hun.head()
# Out:
#    age  sex  chest_pain resting_blod_pressuremm_hg cholesterol_mg/dl  \
# 0   28    1           2                        130               132
# 1   29    1           2                        120               243
# 2   29    1           2                        140                 ?
# 3   30    0           1                        170               237
# 4   31    0           2                        100               219
#
#   fasting_blood_sugar resting_ekg max_heart_rate excersice_induced_angina  \
# 0                   0           2            185                        0
# 1                   0           0            160                        0
# 2                   0           0            170                        0
# 3                   0           1            170                        0
# 4                   0           1            150                        0
#
#    ST_depression_induced_by_exercise_relative_to_rest slope  \
# ...

# %%
lb.head()
# Out:
#    age  sex  chest_pain resting_blod_pressuremm_hg cholesterol_mg/dl  \
# 0   63    1           4                        140               260
# 1   44    1           4                        130               209
# 2   60    1           4                        132               218
# 3   55    1           4                        142               228
# 4   66    1           3                        110               213
#
#   fasting_blood_sugar  resting_ekg max_heart_rate excersice_induced_angina  \
# 0                   0            1            112                        1
# 1                   0            1            127                        0
# 2                   0            1            140                        1
# 3                   0            1            149                        1
# 4                   1            2             99                        1
#
#   ST_depression_induced_by_exercise_relative_to_rest slope  \
# ...

# %%
hr_swi = swi['max_heart_rate']

# %%
clev['age'].hist()

# %%
l = swi['resting_blod_pressuremm_hg']

# %%
l.iloc[2]
# Out:
# '?'

# %%
hr_swi.drop('?', axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-0bc31168496c> in <module>()
# ----> 1 hr_swi.drop('?', axis=0)
#
# /Users/Oren/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, level)
#     402                 new_axis = axis.drop(labels, level=level)
#     403             else:
# --> 404                 new_axis = axis.drop(labels)
#     405             dropped = self.reindex(**{axis_name: new_axis})
#     406             try:
#
# /Users/Oren/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in drop(self, labels)
#    1305         mask = indexer == -1
#    1306         if mask.any():
# -> 1307             raise ValueError('labels %s not contained in axis' % labels[mask])
#    1308         return self.delete(indexer)
#    1309
#
# ValueError: labels ['?'] not contained in axis

# %%
clev['age'].mean(), clev['age'].std()
# Out:
# (54.438943894389439, 9.0386624424467517)

# %%
cnt, bins, ig = plt.hist(clev['age'], 20)

# %%
fig, ax = plt.subplots(1, 4, figsize=(12,3))

ax[0].hist(clev['resting_blod_pressuremm_hg'], 20)
ax[0].set_title('resting bp Cleveland')
# ax[1].hist(swi['resting_blod_pressuremm_hg'], 20)                   
ax[1].set_title('resting bp swiss')
# ax[2].hist(lb['resting_blod_pressuremm_hg'], 20)
ax[2].set_title('resting bp long beach')
ax[3].hist(hun['resting_blod_pressuremm_hg'], 20)                    
ax[3].set_title('resting bp Hungary')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-8072acaa342e> in <module>()
#       7 # ax[2].hist(lb['resting_blod_pressuremm_hg'], 20)
#       8 ax[2].set_title('resting bp long beach')
# ----> 9 ax[3].hist(hun['resting_blod_pressuremm_hg'], 20)
#      10 ax[3].set_title('resting bp Hungary')
#
# /Users/Oren/anaconda/lib/python2.7/site-packages/matplotlib/axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    8324             # this will automatically overwrite bins,
#    8325             # so that each histogram uses the same bins
# -> 8326             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    8327             m = m.astype(float) # causes problems later if it's an int
#    8328             if mlast is None:
#
# ...
